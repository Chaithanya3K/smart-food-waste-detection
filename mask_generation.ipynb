# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaithanya3K/smart-food-waste-detection/blob/main/mask_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import numpy as np
import cv2
from PIL import Image
from glob import glob

# %%
import os
import json
import cv2
import numpy as np

# === Folder paths ===
image_dir = '/content/drive/MyDrive/vgg'                  # folder with original images
json_dir  = '/content/drive/MyDrive/manual_annotations'   # folder with individual VIA JSON files
mask_dir  = '/content/masks1'                              # save masks in Colab runtime
os.makedirs(mask_dir, exist_ok=True)

# === Read all JSON files ===
json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]

for json_file in json_files:
    json_path = os.path.join(json_dir, json_file)
    with open(json_path, 'r') as f:
        data = json.load(f)

    for key, ann in data.items():
        if 'filename' not in ann or 'regions' not in ann:
            print(f"⚠️ Skipping invalid entry: {key}")
            continue

        filename = ann['filename']
        image_path = os.path.join(image_dir, filename)

        if not os.path.exists(image_path):
            print(f"⚠️ Image not found, skipping: {filename}")
            continue

        img = cv2.imread(image_path)
        height, width = img.shape[:2]
        mask = np.zeros((height, width), dtype=np.uint8)

        for region in ann.get('regions', []):
            shape_attr = region['shape_attributes']
            if shape_attr['name'] == 'polygon':
                all_x = shape_attr['all_points_x']
                all_y = shape_attr['all_points_y']
                points = np.array(list(zip(all_x, all_y)), dtype=np.int32)
                cv2.fillPoly(mask, [points], 255)

        mask_filename = os.path.splitext(filename)[0] + '_mask.png'
        mask_path = os.path.join(mask_dir, mask_filename)
        cv2.imwrite(mask_path, mask)

        if os.path.exists(mask_path):
            print(f"✅ Saved mask in Colab: {mask_filename}")
        else:
            print(f"❌ Failed to save: {mask_filename}")
# Out:
# ⚠️ Skipping invalid entry: _via_settings
# ⚠️ Skipping invalid entry: _via_img_metadata
# ⚠️ Skipping invalid entry: _via_attributes
# ⚠️ Skipping invalid entry: _via_data_format_version
# ⚠️ Skipping invalid entry: _via_image_id_list
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ...
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
# ✅ Saved mask in Colab: image95_mask.png
# ✅ Saved mask in Colab: image_1_mask.png
# ✅ Saved mask in Colab: image_2_mask.png
# ✅ Saved mask in Colab: image_3_mask.png
# ✅ Saved mask in Colab: image_4_mask.png
# ✅ Saved mask in Colab: image_5_mask.png
# ✅ Saved mask in Colab: image_6_mask.png
# ✅ Saved mask in Colab: image_7_mask.png
# ✅ Saved mask in Colab: image_8_mask.png
# ✅ Saved mask in Colab: image_9_mask.png
# ✅ Saved mask in Colab: image_10_mask.png
# ✅ Saved mask in Colab: image_11_mask.png
# ✅ Saved mask in Colab: image_12_mask.png
# ✅ Saved mask in Colab: image_13_mask.png
# ✅ Saved mask in Colab: image_14_mask.png
# ✅ Saved mask in Colab: image_15_mask.png
# ✅ Saved mask in Colab: image_16_mask.png
# ✅ Saved mask in Colab: image_17_mask.png
# ✅ Saved mask in Colab: image_18_mask.png
# ✅ Saved mask in Colab: image_19_mask.png
# ✅ Saved mask in Colab: Image_20_mask.png
# ✅ Saved mask in Colab: image_21_mask.png
# ✅ Saved mask in Colab: image_22_mask.png
# ✅ Saved mask in Colab: image_23_mask.png
# ✅ Saved mask in Colab: image_24_mask.png
# ✅ Saved mask in Colab: image25_mask.png
# ✅ Saved mask in Colab: image28_mask.png
# ✅ Saved mask in Colab: image29_mask.png
# ✅ Saved mask in Colab: image30_mask.png
# ✅ Saved mask in Colab: image31_mask.png
# ✅ Saved mask in Colab: image32_mask.png
# ✅ Saved mask in Colab: image33_mask.png
# ✅ Saved mask in Colab: image34_mask.png
# ✅ Saved mask in Colab: image35_mask.png
# ✅ Saved mask in Colab: image36_mask.png
# ✅ Saved mask in Colab: image38_mask.png
# ✅ Saved mask in Colab: image39 - Copy_mask.png
# ✅ Saved mask in Colab: image40_mask.png
# ✅ Saved mask in Colab: image41 - Copy_mask.png
# ✅ Saved mask in Colab: image42 - Copy_mask.png
# ✅ Saved mask in Colab: image43 - Copy_mask.png
# ✅ Saved mask in Colab: image44_mask.png
# ✅ Saved mask in Colab: image45 - Copy_mask.png
# ✅ Saved mask in Colab: image46 - Copy_mask.png
# ✅ Saved mask in Colab: image85_mask.png
# ✅ Saved mask in Colab: image94_mask.png
